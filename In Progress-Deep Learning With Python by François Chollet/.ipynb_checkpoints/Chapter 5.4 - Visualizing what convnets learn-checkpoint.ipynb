# %% [markdown]
# # Chapter 5.4 - Visualizing what convnets learn

# %% [markdown]
# ## Loading model from the previous chapter

# %%
# Importing module to load a pre-trained model.
from keras.models import load_model
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
model = load_model('./saved_checkpoints/Chapter 5.2 - Using convets with small datasets/cats_and_dogs_small_2.h5')

# %%
# Summary
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_5 (Conv2D)            (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 34, 34, 128)       73856
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 17, 17, 128)       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 15, 15, 128)       147584
# ...

# %% [markdown]
# ## Example data preprocessing

# %%
# Path
img_path = 'E:/1_GitHub/arcyfelix/Courses/In Progress-Deep Learning With Python by François Chollet/data/Chapter 5.2 - Using convets with small datasets/test/cats/cat.1752.jpg'

# %%
from keras.preprocessing import image
import numpy as np

# %% [markdown]
# ### Preprocessing the image into a 4D tensor

# %%
img = image.load_img(img_path, 
                     target_size = (150, 150))

img_tensor = image.img_to_array(img)

# %%
img_tensor.shape
# Out:
# (150, 150, 3)

# %%
img_tensor = np.expand_dims(img_tensor, 
                            axis = 0)

# %%
img_tensor.shape
# Out:
# (1, 150, 150, 3)

# %%
# Remember that the model was trained on inputs
# that were preprocessed in the following way:
img_tensor /= 255.

# %%
import matplotlib.pyplot as plt

plt.imshow(img_tensor[0])
plt.show()
